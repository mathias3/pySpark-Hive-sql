# %%
txt = sc.textFile('wasb:///example/data/gutenberg/ulysses.txt')
txt.first()
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>application_1481663241061_0006</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://hn0-mysia.w5sscwjcovzurhnhqtvgx3v52b.bx.internal.cloudapp.net:8088/proxy/application_1481663241061_0006/">Link</a></td><td><a target="_blank" href="http://10.0.0.18:30060/node/containerlogs/container_1481663241061_0006_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkContext available as 'sc'.
# HiveContext available as 'sqlContext'.
# u'The Project Gutenberg EBook of Ulysses, by James Joyce'

# %%
txt.count()
# Out:
# 33055
